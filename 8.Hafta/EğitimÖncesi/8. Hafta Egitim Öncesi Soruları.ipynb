# %% [markdown]
# # Problem 1
# Kullanıcıdan aldığı ürün bilgisini (ad, fiyat) urunler.txt dosyasına kayıt eden fonksiyonu yazınız.

# %%
with open("urun.txt","a",encoding="utf-8") as file:
 while True:
  veri1 = input("Ürünün adını giriniz : ")
  veri2 = input("Ürünün fiyatını giriniz : ")
  file.write(veri1 + "," + veri2 + "\n")
  break

# %% [markdown]
# # Problem 2
# 1.problemde oluşturulan text dosyası içerisinde kullanıcıdan alacağımız eski kelime isimli değişkene atadığımız
# ve değiştirilmesini istediğimiz kelimemizi yerini alıcak olan yeni kelime isimli değişkene atayın. Belirlenen kelimeleri text dosyasında değiştiren fonksiyonu yazınız.

# %%
def kelimeDegis(eskiKelime,yeniKelime,dosyaAd):
    with open( "urun.txt" , "r",encoding="utf-8") as file:
        metin = file.read()
    metin = metin.replace(eskiKelime, yeniKelime)
    with open("urun.txt", "w", encoding= "utf-8") as file:
        file.write(metin)
kelimeDegis("Çikolata","Cipsi","urun.txt")

# %% [markdown]
# # Problem 3
# Vehicle sınıfının tüm değişkenlerini ve yöntemlerini devralacak bir alt sınıf olarak Bus sınıfı oluşturunuz.
#
#
#
# ```
# Output
# > Name: School Volvo Speed: 180 Mileage: 12
# ```

# %%
class Bus():
    def __init__(self,name,speed,milage):
        self.name = name
        self.speed = speed
        self.milage = milage

bus1 = Bus("School Volvo","180","12")

print(f"Name : {bus1.name} \nSpeed: {bus1.speed} \nMileage: {bus1.milage}")
# Out:
# Name : School Volvo
# Speed: 180
# Mileage: 12
